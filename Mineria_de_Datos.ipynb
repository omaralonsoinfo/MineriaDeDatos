# %% [markdown]
# <a href="https://colab.research.google.com/github/omaralonsoinfo/MineriaDeDatos/blob/main/Mineria_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mineria de Datos

# %% [markdown]
# ## Primer Parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# #### Ciencia de Datos

# %% [markdown]
#  La ciencia de datos es un campo que combina matemáticas, estadística, programación y herramientas tecnológicas para analizar grandes cantidades de información y descubrir patrones

# %% [markdown]
# #### Mineria de Datos

# %% [markdown]
#  La minería de datos es el proceso de buscar patrones y conocimientos escondidos dentro de grandes cantidades de información, como si estuvieras buscando pepitas de oro en una mina.

# %% [markdown]
# #### Tarea 1

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.
